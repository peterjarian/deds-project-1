# %% [markdown]
# # Data Warehouse

# %% [markdown]
# ## Imports

# %%
import mysql.connector
import pandas as pd
import warnings
from datetime import datetime

warnings.filterwarnings(
    "ignore",
    message="pandas only supports SQLAlchemy connectable",
    category=UserWarning,
)

# %% [markdown]
# ## Connection

# %% [markdown]
# ### Staging Area

# %%
staging_area_conn = mysql.connector.connect(host="host.docker.internal", user="deds", passwd="deds", database="deds")
staging_area_cursor = staging_area_conn.cursor()

# %% [markdown]
# ### Data Warehouse

# %%
warehouse_conn = mysql.connector.connect(
    host="host.docker.internal", user="deds", passwd="deds", database="warehouse", port=3307
)
warehouse_cursor = warehouse_conn.cursor()

# %% [markdown]
# ## Reset database

# %%
warehouse_cursor.execute("DELETE FROM DimProduct")
warehouse_cursor.execute("DELETE FROM DimVendor")
warehouse_cursor.execute("DELETE FROM DimEmployee")

warehouse_conn.commit()

# %% [markdown]
# ## Tables

# %% [markdown]
# ### Product

# %%
def create_product_row(
    id,
    name,
    color,
    size,
    size_unit_measure_code,
    weight,
    weight_unit_measure_code,
    discontinued,
    standard_cost,
    price,
    safety_stock_level,
    reorder_point,
    product_category_name,
):
    def handle_nan(value):
        return None if pd.isnull(value) else value

    id = handle_nan(id)
    name = handle_nan(name)
    color = handle_nan(color)
    size = handle_nan(size)
    size_unit_measure_code = handle_nan(size_unit_measure_code)
    weight = handle_nan(weight)
    weight_unit_measure_code = handle_nan(weight_unit_measure_code)
    discontinued = handle_nan(discontinued)
    standard_cost = handle_nan(standard_cost)
    price = handle_nan(price)
    safety_stock_level = handle_nan(safety_stock_level)
    reorder_point = handle_nan(reorder_point)
    product_category_name = handle_nan(product_category_name)

    query = """
    INSERT INTO DimProduct (
        ProductID, Name, Color, Size, SizeUnitMeasureCode, Weight, WeightUnitMeasureCode,
        Discontinued, StandardCost, Price, SafetyStockLevel, ReorderPoint, ProductCategoryName
    ) VALUES (
        # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s
    )
    """

    values = (
        id,
        name,
        color,
        size,
        size_unit_measure_code,
        weight,
        weight_unit_measure_code,
        discontinued,
        standard_cost,
        price,
        safety_stock_level,
        reorder_point,
        product_category_name,
    )

    try:
        warehouse_cursor.execute(query, values)
        print(f"Successfully loaded product {id} into warehouse")
    except mysql.connector.Error as err:
        print(values)
        print(f"Failed to load product into warehouse: {err}")

    warehouse_conn.commit()


staging_area_product_data = pd.read_sql_query("SELECT * FROM Product", staging_area_conn)


for row in staging_area_product_data.itertuples():
    id = row.ProductID
    name = row.ProductName
    color = row.Color
    size = row.Size
    size_unit_measure_code = row.SizeUnitMeasureCode
    weight = row.Weight
    weight_unit_measure_code = row.WeightUnitMeasureCode

    discontinued = False

    staging_area_product_data["DiscontinuedDate"] = pd.to_datetime(staging_area_product_data["DiscontinuedDate"])
    current_date = datetime.now()

    if row.Discontinued == 1:
        discontinued = True
    # check if the discontinued date is already happend then set it to true
    elif row.DiscontinuedDate and row.DiscontinuedDate < current_date:
        discontinued = True

    standard_cost = row.StandardCost

    # price: we combine multiple prices into one price
    price = row.ListPrice

    if pd.isnull(price):
        price = row.UnitPrice

    safety_stock_level = row.SafetyStockLevel

    reorder_point = row.ReorderPoint

    if pd.isnull(reorder_point):
        reorder_point = row.ReorderLevel

    product_category_name = None

    if pd.notnull(row.ProductCategoryID):
        result = pd.read_sql_query(
            f"SELECT Name FROM ProductCategory WHERE ProductCategoryID = {row.ProductCategoryID}", staging_area_conn
        )
        if not result.empty:
            product_category_name = result.iloc[0].Name
    elif pd.notnull(row.category):
        product_category_name = row.category

    create_product_row(
        id,
        name,
        color,
        size,
        size_unit_measure_code,
        weight,
        weight_unit_measure_code,
        discontinued,
        standard_cost,
        price,
        safety_stock_level,
        reorder_point,
        product_category_name,
    )
# Out:
# Successfully loaded product 1 into warehouse
# Successfully loaded product 2 into warehouse
# Successfully loaded product 3 into warehouse
# Successfully loaded product 4 into warehouse
# Successfully loaded product 5 into warehouse
# Successfully loaded product 6 into warehouse
# Successfully loaded product 7 into warehouse
# Successfully loaded product 8 into warehouse
# Successfully loaded product 9 into warehouse
# Successfully loaded product 10 into warehouse
# Successfully loaded product 11 into warehouse
# Successfully loaded product 12 into warehouse
# Successfully loaded product 13 into warehouse
# Successfully loaded product 14 into warehouse
# Successfully loaded product 15 into warehouse
# Successfully loaded product 16 into warehouse
# Successfully loaded product 17 into warehouse
# Successfully loaded product 18 into warehouse
# Successfully loaded product 19 into warehouse
# Successfully loaded product 20 into warehouse
# Successfully loaded product 21 into warehouse
# Successfully loaded product 22 into warehouse
# Successfully loaded product 23 into warehouse
# Successfully loaded product 24 into warehouse
# Successfully loaded product 25 into warehouse
# Successfully loaded product 26 into warehouse
# Successfully loaded product 27 into warehouse
# Successfully loaded product 28 into warehouse
# Successfully loaded product 29 into warehouse
# Successfully loaded product 30 into warehouse
# Successfully loaded product 31 into warehouse
# Successfully loaded product 32 into warehouse
# Successfully loaded product 33 into warehouse
# Successfully loaded product 34 into warehouse
# Successfully loaded product 35 into warehouse
# Successfully loaded product 36 into warehouse
# Successfully loaded product 37 into warehouse
# Successfully loaded product 38 into warehouse
# Successfully loaded product 39 into warehouse
# Successfully loaded product 40 into warehouse
# Successfully loaded product 41 into warehouse
# Successfully loaded product 42 into warehouse
# Successfully loaded product 43 into warehouse
# Successfully loaded product 44 into warehouse
# Successfully loaded product 45 into warehouse
# Successfully loaded product 46 into warehouse
# Successfully loaded product 47 into warehouse
# Successfully loaded product 48 into warehouse
# Successfully loaded product 49 into warehouse
# Successfully loaded product 50 into warehouse
# Successfully loaded product 51 into warehouse
# Successfully loaded product 52 into warehouse
# Successfully loaded product 53 into warehouse
# Successfully loaded product 54 into warehouse
# Successfully loaded product 55 into warehouse
# Successfully loaded product 56 into warehouse
# Successfully loaded product 57 into warehouse
# Successfully loaded product 58 into warehouse
# Successfully loaded product 59 into warehouse
# Successfully loaded product 60 into warehouse
# Successfully loaded product 61 into warehouse
# Successfully loaded product 62 into warehouse
# Successfully loaded product 63 into warehouse
# Successfully loaded product 64 into warehouse
# Successfully loaded product 65 into warehouse
# Successfully loaded product 66 into warehouse
# Successfully loaded product 67 into warehouse
# Successfully loaded product 68 into warehouse
# Successfully loaded product 69 into warehouse
# Successfully loaded product 70 into warehouse
# Successfully loaded product 71 into warehouse
# Successfully loaded product 72 into warehouse
# Successfully loaded product 73 into warehouse
# Successfully loaded product 74 into warehouse
# Successfully loaded product 75 into warehouse
# Successfully loaded product 76 into warehouse
# Successfully loaded product 77 into warehouse
# Successfully loaded product 300 into warehouse
# Successfully loaded product 301 into warehouse
# Successfully loaded product 302 into warehouse
# Successfully loaded product 316 into warehouse
# Successfully loaded product 317 into warehouse
# Successfully loaded product 318 into warehouse
# Successfully loaded product 319 into warehouse
# Successfully loaded product 320 into warehouse
# Successfully loaded product 321 into warehouse
# Successfully loaded product 322 into warehouse
# Successfully loaded product 323 into warehouse
# Successfully loaded product 324 into warehouse
# Successfully loaded product 325 into warehouse
# Successfully loaded product 326 into warehouse
# Successfully loaded product 327 into warehouse
# Successfully loaded product 328 into warehouse
# Successfully loaded product 329 into warehouse
# Successfully loaded product 330 into warehouse
# Successfully loaded product 331 into warehouse
# Successfully loaded product 332 into warehouse
# Successfully loaded product 341 into warehouse
# Successfully loaded product 342 into warehouse
# Successfully loaded product 343 into warehouse
# Successfully loaded product 344 into warehouse
# Successfully loaded product 345 into warehouse
# Successfully loaded product 346 into warehouse
# Successfully loaded product 347 into warehouse
# Successfully loaded product 348 into warehouse
# Successfully loaded product 349 into warehouse
# Successfully loaded product 350 into warehouse
# Successfully loaded product 351 into warehouse
# Successfully loaded product 352 into warehouse
# Successfully loaded product 355 into warehouse
# Successfully loaded product 356 into warehouse
# Successfully loaded product 357 into warehouse
# Successfully loaded product 358 into warehouse
# Successfully loaded product 359 into warehouse
# Successfully loaded product 360 into warehouse
# Successfully loaded product 361 into warehouse
# Successfully loaded product 362 into warehouse
# Successfully loaded product 363 into warehouse
# Successfully loaded product 364 into warehouse
# Successfully loaded product 365 into warehouse
# Successfully loaded product 366 into warehouse
# Successfully loaded product 367 into warehouse
# Successfully loaded product 368 into warehouse
# Successfully loaded product 369 into warehouse
# Successfully loaded product 370 into warehouse
# Successfully loaded product 371 into warehouse
# Successfully loaded product 372 into warehouse
# Successfully loaded product 373 into warehouse
# Successfully loaded product 374 into warehouse
# Successfully loaded product 375 into warehouse
# Successfully loaded product 376 into warehouse
# Successfully loaded product 377 into warehouse
# Successfully loaded product 378 into warehouse
# Successfully loaded product 379 into warehouse
# Successfully loaded product 380 into warehouse
# Successfully loaded product 381 into warehouse
# Successfully loaded product 382 into warehouse
# Successfully loaded product 383 into warehouse
# Successfully loaded product 384 into warehouse
# Successfully loaded product 385 into warehouse
# Successfully loaded product 386 into warehouse
# Successfully loaded product 387 into warehouse
# Successfully loaded product 388 into warehouse
# Successfully loaded product 389 into warehouse
# Successfully loaded product 390 into warehouse
# Successfully loaded product 391 into warehouse
# Successfully loaded product 392 into warehouse
# Successfully loaded product 393 into warehouse
# Successfully loaded product 394 into warehouse
# Successfully loaded product 395 into warehouse
# Successfully loaded product 396 into warehouse
# Successfully loaded product 397 into warehouse
# Successfully loaded product 398 into warehouse
# Successfully loaded product 399 into warehouse
# Successfully loaded product 400 into warehouse
# Successfully loaded product 401 into warehouse
# Successfully loaded product 402 into warehouse
# Successfully loaded product 403 into warehouse
# Successfully loaded product 404 into warehouse
# Successfully loaded product 405 into warehouse
# Successfully loaded product 406 into warehouse
# Successfully loaded product 407 into warehouse
# Successfully loaded product 408 into warehouse
# Successfully loaded product 409 into warehouse
# Successfully loaded product 410 into warehouse
# Successfully loaded product 411 into warehouse
# Successfully loaded product 412 into warehouse
# Successfully loaded product 413 into warehouse
# Successfully loaded product 414 into warehouse
# Successfully loaded product 415 into warehouse
# Successfully loaded product 416 into warehouse
# Successfully loaded product 417 into warehouse
# Successfully loaded product 418 into warehouse
# Successfully loaded product 419 into warehouse
# Successfully loaded product 420 into warehouse
# Successfully loaded product 421 into warehouse
# Successfully loaded product 422 into warehouse
# Successfully loaded product 423 into warehouse
# Successfully loaded product 424 into warehouse
# Successfully loaded product 425 into warehouse
# Successfully loaded product 426 into warehouse
# Successfully loaded product 427 into warehouse
# Successfully loaded product 428 into warehouse
# Successfully loaded product 429 into warehouse
# Successfully loaded product 430 into warehouse
# Successfully loaded product 431 into warehouse
# Successfully loaded product 432 into warehouse
# Successfully loaded product 433 into warehouse
# Successfully loaded product 434 into warehouse
# Successfully loaded product 435 into warehouse
# Successfully loaded product 436 into warehouse
# Successfully loaded product 437 into warehouse
# Successfully loaded product 438 into warehouse
# Successfully loaded product 439 into warehouse
# Successfully loaded product 440 into warehouse
# Successfully loaded product 441 into warehouse
# Successfully loaded product 442 into warehouse
# Successfully loaded product 443 into warehouse
# Successfully loaded product 444 into warehouse
# Successfully loaded product 445 into warehouse
# Successfully loaded product 446 into warehouse
# Successfully loaded product 447 into warehouse
# Successfully loaded product 448 into warehouse
# Successfully loaded product 449 into warehouse
# Successfully loaded product 450 into warehouse
# Successfully loaded product 451 into warehouse
# Successfully loaded product 452 into warehouse
# Successfully loaded product 453 into warehouse
# Successfully loaded product 454 into warehouse
# Successfully loaded product 455 into warehouse
# Successfully loaded product 456 into warehouse
# Successfully loaded product 457 into warehouse
# Successfully loaded product 458 into warehouse
# Successfully loaded product 459 into warehouse
# Successfully loaded product 460 into warehouse
# Successfully loaded product 461 into warehouse
# Successfully loaded product 462 into warehouse
# Successfully loaded product 463 into warehouse
# Successfully loaded product 464 into warehouse
# Successfully loaded product 465 into warehouse
# Successfully loaded product 466 into warehouse
# Successfully loaded product 467 into warehouse
# Successfully loaded product 468 into warehouse
# Successfully loaded product 469 into warehouse
# Successfully loaded product 470 into warehouse
# Successfully loaded product 471 into warehouse
# Successfully loaded product 472 into warehouse
# Successfully loaded product 473 into warehouse
# Successfully loaded product 474 into warehouse
# Successfully loaded product 475 into warehouse
# Successfully loaded product 476 into warehouse
# Successfully loaded product 477 into warehouse
# Successfully loaded product 478 into warehouse
# Successfully loaded product 479 into warehouse
# Successfully loaded product 480 into warehouse
# Successfully loaded product 481 into warehouse
# Successfully loaded product 482 into warehouse
# Successfully loaded product 483 into warehouse
# Successfully loaded product 484 into warehouse
# Successfully loaded product 485 into warehouse
# Successfully loaded product 486 into warehouse
# Successfully loaded product 487 into warehouse
# Successfully loaded product 488 into warehouse
# Successfully loaded product 489 into warehouse
# Successfully loaded product 490 into warehouse
# Successfully loaded product 491 into warehouse
# Successfully loaded product 492 into warehouse
# Successfully loaded product 493 into warehouse
# Successfully loaded product 494 into warehouse
# Successfully loaded product 495 into warehouse
# Successfully loaded product 496 into warehouse
# Successfully loaded product 497 into warehouse
# Successfully loaded product 500 into warehouse
# Successfully loaded product 501 into warehouse
# Successfully loaded product 504 into warehouse
# Successfully loaded product 505 into warehouse
# Successfully loaded product 506 into warehouse
# Successfully loaded product 507 into warehouse
# Successfully loaded product 508 into warehouse
# Successfully loaded product 509 into warehouse
# Successfully loaded product 510 into warehouse
# Successfully loaded product 511 into warehouse
# Successfully loaded product 512 into warehouse
# Successfully loaded product 513 into warehouse
# Successfully loaded product 514 into warehouse
# Successfully loaded product 515 into warehouse
# Successfully loaded product 516 into warehouse
# Successfully loaded product 517 into warehouse
# Successfully loaded product 518 into warehouse
# Successfully loaded product 519 into warehouse
# Successfully loaded product 520 into warehouse
# Successfully loaded product 521 into warehouse
# Successfully loaded product 522 into warehouse
# Successfully loaded product 523 into warehouse
# Successfully loaded product 524 into warehouse
# Successfully loaded product 525 into warehouse
# Successfully loaded product 526 into warehouse
# Successfully loaded product 527 into warehouse
# Successfully loaded product 528 into warehouse
# Successfully loaded product 529 into warehouse
# Successfully loaded product 530 into warehouse
# Successfully loaded product 531 into warehouse
# Successfully loaded product 532 into warehouse
# Successfully loaded product 533 into warehouse
# Successfully loaded product 534 into warehouse
# Successfully loaded product 535 into warehouse
# Successfully loaded product 600 into warehouse
# Successfully loaded product 601 into warehouse
# Successfully loaded product 679 into warehouse
# Successfully loaded product 680 into warehouse
# Successfully loaded product 700 into warehouse
# Successfully loaded product 706 into warehouse
# Successfully loaded product 707 into warehouse
# Successfully loaded product 708 into warehouse
# Successfully loaded product 709 into warehouse
# Successfully loaded product 710 into warehouse
# Successfully loaded product 711 into warehouse
# Successfully loaded product 712 into warehouse
# Successfully loaded product 713 into warehouse
# Successfully loaded product 714 into warehouse
# Successfully loaded product 715 into warehouse
# Successfully loaded product 716 into warehouse
# Successfully loaded product 717 into warehouse
# Successfully loaded product 718 into warehouse
# Successfully loaded product 719 into warehouse
# Successfully loaded product 720 into warehouse
# Successfully loaded product 721 into warehouse
# Successfully loaded product 722 into warehouse
# Successfully loaded product 723 into warehouse
# Successfully loaded product 724 into warehouse
# Successfully loaded product 725 into warehouse
# Successfully loaded product 726 into warehouse
# Successfully loaded product 727 into warehouse
# Successfully loaded product 728 into warehouse
# Successfully loaded product 729 into warehouse
# Successfully loaded product 730 into warehouse
# Successfully loaded product 731 into warehouse
# Successfully loaded product 732 into warehouse
# Successfully loaded product 733 into warehouse
# Successfully loaded product 734 into warehouse
# Successfully loaded product 735 into warehouse
# Successfully loaded product 736 into warehouse
# Successfully loaded product 737 into warehouse
# Successfully loaded product 738 into warehouse
# Successfully loaded product 739 into warehouse
# Successfully loaded product 740 into warehouse
# Successfully loaded product 741 into warehouse
# Successfully loaded product 742 into warehouse
# Successfully loaded product 743 into warehouse
# Successfully loaded product 744 into warehouse
# Successfully loaded product 745 into warehouse
# Successfully loaded product 746 into warehouse
# Successfully loaded product 747 into warehouse
# Successfully loaded product 748 into warehouse
# Successfully loaded product 749 into warehouse
# Successfully loaded product 750 into warehouse
# Successfully loaded product 751 into warehouse
# Successfully loaded product 752 into warehouse
# Successfully loaded product 753 into warehouse
# Successfully loaded product 754 into warehouse
# Successfully loaded product 755 into warehouse
# Successfully loaded product 756 into warehouse
# Successfully loaded product 757 into warehouse
# Successfully loaded product 758 into warehouse
# Successfully loaded product 759 into warehouse
# Successfully loaded product 760 into warehouse
# Successfully loaded product 761 into warehouse
# Successfully loaded product 762 into warehouse
# Successfully loaded product 763 into warehouse
# Successfully loaded product 764 into warehouse
# Successfully loaded product 765 into warehouse
# Successfully loaded product 766 into warehouse
# Successfully loaded product 767 into warehouse
# Successfully loaded product 768 into warehouse
# Successfully loaded product 769 into warehouse
# Successfully loaded product 770 into warehouse
# Successfully loaded product 771 into warehouse
# Successfully loaded product 772 into warehouse
# Successfully loaded product 773 into warehouse
# Successfully loaded product 774 into warehouse
# Successfully loaded product 775 into warehouse
# Successfully loaded product 776 into warehouse
# Successfully loaded product 777 into warehouse
# Successfully loaded product 778 into warehouse
# Successfully loaded product 779 into warehouse
# Successfully loaded product 780 into warehouse
# Successfully loaded product 781 into warehouse
# Successfully loaded product 782 into warehouse
# Successfully loaded product 783 into warehouse
# Successfully loaded product 784 into warehouse
# Successfully loaded product 785 into warehouse
# Successfully loaded product 786 into warehouse
# Successfully loaded product 787 into warehouse
# Successfully loaded product 788 into warehouse
# Successfully loaded product 789 into warehouse
# Successfully loaded product 790 into warehouse
# Successfully loaded product 791 into warehouse
# Successfully loaded product 792 into warehouse
# Successfully loaded product 793 into warehouse
# Successfully loaded product 794 into warehouse
# Successfully loaded product 795 into warehouse
# Successfully loaded product 796 into warehouse
# Successfully loaded product 797 into warehouse
# Successfully loaded product 798 into warehouse
# Successfully loaded product 799 into warehouse
# Successfully loaded product 800 into warehouse
# Successfully loaded product 801 into warehouse
# Successfully loaded product 802 into warehouse
# Successfully loaded product 803 into warehouse
# Successfully loaded product 804 into warehouse
# Successfully loaded product 805 into warehouse
# Successfully loaded product 806 into warehouse
# Successfully loaded product 807 into warehouse
# Successfully loaded product 808 into warehouse
# Successfully loaded product 809 into warehouse
# Successfully loaded product 810 into warehouse
# Successfully loaded product 811 into warehouse
# Successfully loaded product 812 into warehouse
# Successfully loaded product 813 into warehouse
# Successfully loaded product 814 into warehouse
# Successfully loaded product 815 into warehouse
# Successfully loaded product 816 into warehouse
# Successfully loaded product 817 into warehouse
# Successfully loaded product 818 into warehouse
# Successfully loaded product 819 into warehouse
# Successfully loaded product 820 into warehouse
# Successfully loaded product 821 into warehouse
# Successfully loaded product 822 into warehouse
# Successfully loaded product 823 into warehouse
# Successfully loaded product 824 into warehouse
# Successfully loaded product 825 into warehouse
# Successfully loaded product 826 into warehouse
# Successfully loaded product 827 into warehouse
# Successfully loaded product 828 into warehouse
# Successfully loaded product 829 into warehouse
# Successfully loaded product 830 into warehouse
# Successfully loaded product 831 into warehouse
# Successfully loaded product 832 into warehouse
# Successfully loaded product 833 into warehouse
# Successfully loaded product 834 into warehouse
# Successfully loaded product 835 into warehouse
# Successfully loaded product 836 into warehouse
# Successfully loaded product 837 into warehouse
# Successfully loaded product 838 into warehouse
# Successfully loaded product 839 into warehouse
# Successfully loaded product 840 into warehouse
# Successfully loaded product 841 into warehouse
# Successfully loaded product 842 into warehouse
# Successfully loaded product 843 into warehouse
# Successfully loaded product 844 into warehouse
# Successfully loaded product 845 into warehouse
# Successfully loaded product 846 into warehouse
# Successfully loaded product 847 into warehouse
# Successfully loaded product 848 into warehouse
# Successfully loaded product 849 into warehouse
# Successfully loaded product 850 into warehouse
# Successfully loaded product 851 into warehouse
# Successfully loaded product 852 into warehouse
# Successfully loaded product 853 into warehouse
# Successfully loaded product 854 into warehouse
# Successfully loaded product 855 into warehouse
# Successfully loaded product 856 into warehouse
# Successfully loaded product 857 into warehouse
# Successfully loaded product 858 into warehouse
# Successfully loaded product 859 into warehouse
# Successfully loaded product 860 into warehouse
# Successfully loaded product 861 into warehouse
# Successfully loaded product 862 into warehouse
# Successfully loaded product 863 into warehouse
# Successfully loaded product 864 into warehouse
# Successfully loaded product 865 into warehouse
# Successfully loaded product 866 into warehouse
# Successfully loaded product 867 into warehouse
# Successfully loaded product 868 into warehouse
# Successfully loaded product 869 into warehouse
# Successfully loaded product 870 into warehouse
# Successfully loaded product 871 into warehouse
# Successfully loaded product 872 into warehouse
# Successfully loaded product 873 into warehouse
# Successfully loaded product 874 into warehouse
# Successfully loaded product 875 into warehouse
# Successfully loaded product 876 into warehouse
# Successfully loaded product 877 into warehouse
# Successfully loaded product 878 into warehouse
# Successfully loaded product 879 into warehouse
# Successfully loaded product 880 into warehouse
# Successfully loaded product 881 into warehouse
# Successfully loaded product 882 into warehouse
# Successfully loaded product 883 into warehouse
# Successfully loaded product 884 into warehouse
# Successfully loaded product 885 into warehouse
# Successfully loaded product 886 into warehouse
# Successfully loaded product 887 into warehouse
# Successfully loaded product 888 into warehouse
# Successfully loaded product 889 into warehouse
# Successfully loaded product 890 into warehouse
# Successfully loaded product 891 into warehouse
# Successfully loaded product 892 into warehouse
# Successfully loaded product 893 into warehouse
# Successfully loaded product 894 into warehouse
# Successfully loaded product 895 into warehouse
# Successfully loaded product 896 into warehouse
# Successfully loaded product 897 into warehouse
# Successfully loaded product 898 into warehouse
# Successfully loaded product 899 into warehouse
# Successfully loaded product 900 into warehouse
# Successfully loaded product 901 into warehouse
# Successfully loaded product 902 into warehouse
# Successfully loaded product 903 into warehouse
# Successfully loaded product 904 into warehouse
# Successfully loaded product 905 into warehouse
# Successfully loaded product 906 into warehouse
# Successfully loaded product 907 into warehouse
# Successfully loaded product 908 into warehouse
# Successfully loaded product 909 into warehouse
# Successfully loaded product 910 into warehouse
# Successfully loaded product 911 into warehouse
# Successfully loaded product 912 into warehouse
# Successfully loaded product 913 into warehouse
# Successfully loaded product 914 into warehouse
# Successfully loaded product 915 into warehouse
# Successfully loaded product 916 into warehouse
# Successfully loaded product 917 into warehouse
# Successfully loaded product 918 into warehouse
# Successfully loaded product 919 into warehouse
# Successfully loaded product 920 into warehouse
# Successfully loaded product 921 into warehouse
# Successfully loaded product 922 into warehouse
# Successfully loaded product 923 into warehouse
# Successfully loaded product 924 into warehouse
# Successfully loaded product 925 into warehouse
# Successfully loaded product 926 into warehouse
# Successfully loaded product 927 into warehouse
# Successfully loaded product 928 into warehouse
# Successfully loaded product 929 into warehouse
# Successfully loaded product 930 into warehouse
# Successfully loaded product 931 into warehouse
# Successfully loaded product 932 into warehouse
# Successfully loaded product 933 into warehouse
# Successfully loaded product 934 into warehouse
# Successfully loaded product 935 into warehouse
# Successfully loaded product 936 into warehouse
# Successfully loaded product 937 into warehouse
# Successfully loaded product 938 into warehouse
# Successfully loaded product 939 into warehouse
# Successfully loaded product 940 into warehouse
# Successfully loaded product 941 into warehouse
# Successfully loaded product 942 into warehouse
# Successfully loaded product 943 into warehouse
# Successfully loaded product 944 into warehouse
# Successfully loaded product 945 into warehouse
# Successfully loaded product 946 into warehouse
# Successfully loaded product 947 into warehouse
# Successfully loaded product 948 into warehouse
# Successfully loaded product 949 into warehouse
# Successfully loaded product 950 into warehouse
# Successfully loaded product 951 into warehouse
# Successfully loaded product 952 into warehouse
# Successfully loaded product 953 into warehouse
# Successfully loaded product 954 into warehouse
# Successfully loaded product 955 into warehouse
# Successfully loaded product 956 into warehouse
# Successfully loaded product 957 into warehouse
# Successfully loaded product 958 into warehouse
# Successfully loaded product 959 into warehouse
# Successfully loaded product 960 into warehouse
# Successfully loaded product 961 into warehouse
# Successfully loaded product 962 into warehouse
# Successfully loaded product 963 into warehouse
# Successfully loaded product 964 into warehouse
# Successfully loaded product 965 into warehouse
# Successfully loaded product 966 into warehouse
# Successfully loaded product 967 into warehouse
# Successfully loaded product 968 into warehouse
# Successfully loaded product 969 into warehouse
# Successfully loaded product 970 into warehouse
# Successfully loaded product 971 into warehouse
# Successfully loaded product 972 into warehouse
# Successfully loaded product 973 into warehouse
# Successfully loaded product 974 into warehouse
# Successfully loaded product 975 into warehouse
# Successfully loaded product 976 into warehouse
# Successfully loaded product 977 into warehouse
# Successfully loaded product 978 into warehouse
# Successfully loaded product 979 into warehouse
# Successfully loaded product 980 into warehouse
# Successfully loaded product 981 into warehouse
# Successfully loaded product 982 into warehouse
# Successfully loaded product 983 into warehouse
# Successfully loaded product 984 into warehouse
# Successfully loaded product 985 into warehouse
# Successfully loaded product 986 into warehouse
# Successfully loaded product 987 into warehouse
# Successfully loaded product 988 into warehouse
# Successfully loaded product 989 into warehouse
# Successfully loaded product 990 into warehouse
# Successfully loaded product 991 into warehouse
# Successfully loaded product 992 into warehouse
# Successfully loaded product 993 into warehouse
# Successfully loaded product 994 into warehouse
# Successfully loaded product 995 into warehouse
# Successfully loaded product 996 into warehouse
# Successfully loaded product 997 into warehouse
# Successfully loaded product 998 into warehouse
# Successfully loaded product 999 into warehouse

# %% [markdown]
# ### Vendor

# %%
def create_vendor_row(id, name):
    def handle_nan(value):
        return None if pd.isnull(value) else value

    id = handle_nan(id)
    name = handle_nan(name)

    query = """
    INSERT INTO DimVendor (
        VendorID, Name
    ) VALUES (
        # %s, %s
    )
    """

    values = (id, name)

    try:
        warehouse_cursor.execute(query, values)
        print(f"Successfully loaded vendor {id} into warehouse")
    except mysql.connector.Error as err:
        print(values)
        print(f"Failed to load product into warehouse: {err}")

    warehouse_conn.commit()


staging_area_vendor_data = pd.read_sql_query("SELECT * FROM Vendor", staging_area_conn)

for row in staging_area_vendor_data.itertuples():
    create_vendor_row(row.VendorID, row.Name)
# Out:
# Successfully loaded vendor 1492 into warehouse
# Successfully loaded vendor 1494 into warehouse
# Successfully loaded vendor 1496 into warehouse
# Successfully loaded vendor 1498 into warehouse
# Successfully loaded vendor 1500 into warehouse
# Successfully loaded vendor 1502 into warehouse
# Successfully loaded vendor 1504 into warehouse
# Successfully loaded vendor 1506 into warehouse
# Successfully loaded vendor 1508 into warehouse
# Successfully loaded vendor 1510 into warehouse
# Successfully loaded vendor 1512 into warehouse
# Successfully loaded vendor 1514 into warehouse
# Successfully loaded vendor 1516 into warehouse
# Successfully loaded vendor 1518 into warehouse
# Successfully loaded vendor 1520 into warehouse
# Successfully loaded vendor 1522 into warehouse
# Successfully loaded vendor 1524 into warehouse
# Successfully loaded vendor 1526 into warehouse
# Successfully loaded vendor 1528 into warehouse
# Successfully loaded vendor 1530 into warehouse
# Successfully loaded vendor 1532 into warehouse
# Successfully loaded vendor 1534 into warehouse
# Successfully loaded vendor 1536 into warehouse
# Successfully loaded vendor 1538 into warehouse
# Successfully loaded vendor 1540 into warehouse
# Successfully loaded vendor 1542 into warehouse
# Successfully loaded vendor 1544 into warehouse
# Successfully loaded vendor 1546 into warehouse
# Successfully loaded vendor 1548 into warehouse
# Successfully loaded vendor 1550 into warehouse
# Successfully loaded vendor 1552 into warehouse
# Successfully loaded vendor 1554 into warehouse
# Successfully loaded vendor 1556 into warehouse
# Successfully loaded vendor 1558 into warehouse
# Successfully loaded vendor 1560 into warehouse
# Successfully loaded vendor 1562 into warehouse
# Successfully loaded vendor 1564 into warehouse
# Successfully loaded vendor 1566 into warehouse
# Successfully loaded vendor 1568 into warehouse
# Successfully loaded vendor 1570 into warehouse
# Successfully loaded vendor 1572 into warehouse
# Successfully loaded vendor 1574 into warehouse
# Successfully loaded vendor 1576 into warehouse
# Successfully loaded vendor 1578 into warehouse
# Successfully loaded vendor 1580 into warehouse
# Successfully loaded vendor 1582 into warehouse
# Successfully loaded vendor 1584 into warehouse
# Successfully loaded vendor 1586 into warehouse
# Successfully loaded vendor 1588 into warehouse
# Successfully loaded vendor 1590 into warehouse
# Successfully loaded vendor 1592 into warehouse
# Successfully loaded vendor 1594 into warehouse
# Successfully loaded vendor 1596 into warehouse
# Successfully loaded vendor 1598 into warehouse
# Successfully loaded vendor 1600 into warehouse
# Successfully loaded vendor 1602 into warehouse
# Successfully loaded vendor 1604 into warehouse
# Successfully loaded vendor 1606 into warehouse
# Successfully loaded vendor 1608 into warehouse
# Successfully loaded vendor 1610 into warehouse
# Successfully loaded vendor 1612 into warehouse
# Successfully loaded vendor 1614 into warehouse
# Successfully loaded vendor 1616 into warehouse
# Successfully loaded vendor 1618 into warehouse
# Successfully loaded vendor 1620 into warehouse
# Successfully loaded vendor 1622 into warehouse
# Successfully loaded vendor 1624 into warehouse
# Successfully loaded vendor 1626 into warehouse
# Successfully loaded vendor 1628 into warehouse
# Successfully loaded vendor 1630 into warehouse
# Successfully loaded vendor 1632 into warehouse
# Successfully loaded vendor 1634 into warehouse
# Successfully loaded vendor 1636 into warehouse
# Successfully loaded vendor 1638 into warehouse
# Successfully loaded vendor 1640 into warehouse
# Successfully loaded vendor 1642 into warehouse
# Successfully loaded vendor 1644 into warehouse
# Successfully loaded vendor 1646 into warehouse
# Successfully loaded vendor 1648 into warehouse
# Successfully loaded vendor 1650 into warehouse
# Successfully loaded vendor 1652 into warehouse
# Successfully loaded vendor 1654 into warehouse
# Successfully loaded vendor 1656 into warehouse
# Successfully loaded vendor 1658 into warehouse
# Successfully loaded vendor 1660 into warehouse
# Successfully loaded vendor 1662 into warehouse
# Successfully loaded vendor 1664 into warehouse
# Successfully loaded vendor 1666 into warehouse
# Successfully loaded vendor 1668 into warehouse
# Successfully loaded vendor 1670 into warehouse
# Successfully loaded vendor 1672 into warehouse
# Successfully loaded vendor 1674 into warehouse
# Successfully loaded vendor 1676 into warehouse
# Successfully loaded vendor 1678 into warehouse
# Successfully loaded vendor 1680 into warehouse
# Successfully loaded vendor 1682 into warehouse
# Successfully loaded vendor 1684 into warehouse
# Successfully loaded vendor 1686 into warehouse
# Successfully loaded vendor 1688 into warehouse
# Successfully loaded vendor 1690 into warehouse
# Successfully loaded vendor 1692 into warehouse
# Successfully loaded vendor 1694 into warehouse
# Successfully loaded vendor 1696 into warehouse
# Successfully loaded vendor 1698 into warehouse

# %% [markdown]
# ### Employee

# %%
def create_employee_row(id, first_name, last_name, department_name, department_group_name):
    def handle_nan(value):
        return None if pd.isnull(value) else value

    id = handle_nan(id)
    first_name = handle_nan(first_name)
    last_name = handle_nan(last_name)
    department_name = handle_nan(department_name)
    department_group_name = handle_nan(department_group_name)

    query = """
    INSERT INTO DimEmployee (
        EmployeeID, FirstName, LastName,
        DepartmentName, DepartmentGroupName
    ) VALUES (
        # %s, %s, %s, %s, %s
    )
    """

    values = (id, first_name, last_name, department_name, department_group_name)

    try:
        warehouse_cursor.execute(query, values)
        print(f"Successfully loaded employee {id} into warehouse")
    except mysql.connector.Error as err:
        print(values)
        print(f"Failed to load employee into warehouse: {err}")

    warehouse_conn.commit()


staging_area_employee_data = pd.read_sql_query("SELECT * FROM Employee", staging_area_conn)

for row in staging_area_employee_data.itertuples():
    id = row.EmployeeID

    first_name = row.FirstName
    if pd.isnull(first_name):
        # get from Person table
        result = pd.read_sql_query(f"SELECT FirstName FROM Person WHERE PersonID = {row.EmployeeID}", staging_area_conn)
        if not result.empty:
            first_name = result.iloc[0].FirstName

    last_name = row.LastName
    if pd.isnull(last_name):
        # get from Person table
        result = pd.read_sql_query(f"SELECT LastName FROM Person WHERE PersonID = {row.EmployeeID}", staging_area_conn)
        if not result.empty:
            last_name = result.iloc[0].LastName

    department_name = None
    department_group_name = None

    # department
    if not pd.isnull(row.DepartmentID):
        result = pd.read_sql_query(
            f"SELECT Name, GroupName FROM Department WHERE DepartmentID = {row.DepartmentID}", staging_area_conn
        )
        if not result.empty:
            department_name = result.iloc[0].Name
            department_group_name = result.iloc[0].GroupName

    create_employee_row(id, first_name, last_name, department_name, department_group_name)
# Out:
# Successfully loaded employee 1 into warehouse
# Successfully loaded employee 2 into warehouse
# Successfully loaded employee 3 into warehouse
# Successfully loaded employee 4 into warehouse
# Successfully loaded employee 5 into warehouse
# Successfully loaded employee 6 into warehouse
# Successfully loaded employee 7 into warehouse
# Successfully loaded employee 8 into warehouse
# Successfully loaded employee 9 into warehouse
# Successfully loaded employee 10 into warehouse
# Successfully loaded employee 11 into warehouse
# Successfully loaded employee 12 into warehouse
# Successfully loaded employee 13 into warehouse
# Successfully loaded employee 14 into warehouse
# Successfully loaded employee 15 into warehouse
# Successfully loaded employee 16 into warehouse
# Successfully loaded employee 17 into warehouse
# Successfully loaded employee 18 into warehouse
# Successfully loaded employee 19 into warehouse
# Successfully loaded employee 20 into warehouse
# Successfully loaded employee 21 into warehouse
# Successfully loaded employee 22 into warehouse
# Successfully loaded employee 23 into warehouse
# Successfully loaded employee 24 into warehouse
# Successfully loaded employee 25 into warehouse
# Successfully loaded employee 26 into warehouse
# Successfully loaded employee 27 into warehouse
# Successfully loaded employee 28 into warehouse
# Successfully loaded employee 29 into warehouse
# Successfully loaded employee 30 into warehouse
# Successfully loaded employee 31 into warehouse
# Successfully loaded employee 32 into warehouse
# Successfully loaded employee 33 into warehouse
# Successfully loaded employee 34 into warehouse
# Successfully loaded employee 35 into warehouse
# Successfully loaded employee 36 into warehouse
# Successfully loaded employee 37 into warehouse
# Successfully loaded employee 38 into warehouse
# Successfully loaded employee 39 into warehouse
# Successfully loaded employee 40 into warehouse
# Successfully loaded employee 41 into warehouse
# Successfully loaded employee 42 into warehouse
# Successfully loaded employee 43 into warehouse
# Successfully loaded employee 44 into warehouse
# Successfully loaded employee 45 into warehouse
# Successfully loaded employee 46 into warehouse
# Successfully loaded employee 47 into warehouse
# Successfully loaded employee 48 into warehouse
# Successfully loaded employee 49 into warehouse
# Successfully loaded employee 50 into warehouse
# Successfully loaded employee 51 into warehouse
# Successfully loaded employee 52 into warehouse
# Successfully loaded employee 53 into warehouse
# Successfully loaded employee 54 into warehouse
# Successfully loaded employee 55 into warehouse
# Successfully loaded employee 56 into warehouse
# Successfully loaded employee 57 into warehouse
# Successfully loaded employee 58 into warehouse
# Successfully loaded employee 59 into warehouse
# Successfully loaded employee 60 into warehouse
# Successfully loaded employee 61 into warehouse
# Successfully loaded employee 62 into warehouse
# Successfully loaded employee 63 into warehouse
# Successfully loaded employee 64 into warehouse
# Successfully loaded employee 65 into warehouse
# Successfully loaded employee 66 into warehouse
# Successfully loaded employee 67 into warehouse
# Successfully loaded employee 68 into warehouse
# Successfully loaded employee 69 into warehouse
# Successfully loaded employee 70 into warehouse
# Successfully loaded employee 71 into warehouse
# Successfully loaded employee 72 into warehouse
# Successfully loaded employee 73 into warehouse
# Successfully loaded employee 74 into warehouse
# Successfully loaded employee 75 into warehouse
# Successfully loaded employee 76 into warehouse
# Successfully loaded employee 77 into warehouse
# Successfully loaded employee 78 into warehouse
# Successfully loaded employee 79 into warehouse
# Successfully loaded employee 80 into warehouse
# Successfully loaded employee 81 into warehouse
# Successfully loaded employee 82 into warehouse
# Successfully loaded employee 83 into warehouse
# Successfully loaded employee 84 into warehouse
# Successfully loaded employee 85 into warehouse
# Successfully loaded employee 86 into warehouse
# Successfully loaded employee 87 into warehouse
# Successfully loaded employee 88 into warehouse
# Successfully loaded employee 89 into warehouse
# Successfully loaded employee 90 into warehouse
# Successfully loaded employee 91 into warehouse
# Successfully loaded employee 92 into warehouse
# Successfully loaded employee 93 into warehouse
# Successfully loaded employee 94 into warehouse
# Successfully loaded employee 95 into warehouse
# Successfully loaded employee 96 into warehouse
# Successfully loaded employee 97 into warehouse
# Successfully loaded employee 98 into warehouse
# Successfully loaded employee 99 into warehouse
# Successfully loaded employee 100 into warehouse
# Successfully loaded employee 101 into warehouse
# Successfully loaded employee 102 into warehouse
# Successfully loaded employee 103 into warehouse
# Successfully loaded employee 104 into warehouse
# Successfully loaded employee 105 into warehouse
# Successfully loaded employee 106 into warehouse
# Successfully loaded employee 107 into warehouse
# Successfully loaded employee 108 into warehouse
# Successfully loaded employee 109 into warehouse
# Successfully loaded employee 110 into warehouse
# Successfully loaded employee 111 into warehouse
# Successfully loaded employee 112 into warehouse
# Successfully loaded employee 113 into warehouse
# Successfully loaded employee 114 into warehouse
# Successfully loaded employee 115 into warehouse
# Successfully loaded employee 116 into warehouse
# Successfully loaded employee 117 into warehouse
# Successfully loaded employee 118 into warehouse
# Successfully loaded employee 119 into warehouse
# Successfully loaded employee 120 into warehouse
# Successfully loaded employee 121 into warehouse
# Successfully loaded employee 122 into warehouse
# Successfully loaded employee 123 into warehouse
# Successfully loaded employee 124 into warehouse
# Successfully loaded employee 125 into warehouse
# Successfully loaded employee 126 into warehouse
# Successfully loaded employee 127 into warehouse
# Successfully loaded employee 128 into warehouse
# Successfully loaded employee 129 into warehouse
# Successfully loaded employee 130 into warehouse
# Successfully loaded employee 131 into warehouse
# Successfully loaded employee 132 into warehouse
# Successfully loaded employee 133 into warehouse
# Successfully loaded employee 134 into warehouse
# Successfully loaded employee 135 into warehouse
# Successfully loaded employee 136 into warehouse
# Successfully loaded employee 137 into warehouse
# Successfully loaded employee 138 into warehouse
# Successfully loaded employee 139 into warehouse
# Successfully loaded employee 140 into warehouse
# Successfully loaded employee 141 into warehouse
# Successfully loaded employee 142 into warehouse
# Successfully loaded employee 143 into warehouse
# Successfully loaded employee 144 into warehouse
# Successfully loaded employee 145 into warehouse
# Successfully loaded employee 146 into warehouse
# Successfully loaded employee 147 into warehouse
# Successfully loaded employee 148 into warehouse
# Successfully loaded employee 149 into warehouse
# Successfully loaded employee 150 into warehouse
# Successfully loaded employee 151 into warehouse
# Successfully loaded employee 152 into warehouse
# Successfully loaded employee 153 into warehouse
# Successfully loaded employee 154 into warehouse
# Successfully loaded employee 155 into warehouse
# Successfully loaded employee 156 into warehouse
# Successfully loaded employee 157 into warehouse
# Successfully loaded employee 158 into warehouse
# Successfully loaded employee 159 into warehouse
# Successfully loaded employee 160 into warehouse
# Successfully loaded employee 161 into warehouse
# Successfully loaded employee 162 into warehouse
# Successfully loaded employee 163 into warehouse
# Successfully loaded employee 164 into warehouse
# Successfully loaded employee 165 into warehouse
# Successfully loaded employee 166 into warehouse
# Successfully loaded employee 167 into warehouse
# Successfully loaded employee 168 into warehouse
# Successfully loaded employee 169 into warehouse
# Successfully loaded employee 170 into warehouse
# Successfully loaded employee 171 into warehouse
# Successfully loaded employee 172 into warehouse
# Successfully loaded employee 173 into warehouse
# Successfully loaded employee 174 into warehouse
# Successfully loaded employee 175 into warehouse
# Successfully loaded employee 176 into warehouse
# Successfully loaded employee 177 into warehouse
# Successfully loaded employee 178 into warehouse
# Successfully loaded employee 179 into warehouse
# Successfully loaded employee 180 into warehouse
# Successfully loaded employee 181 into warehouse
# Successfully loaded employee 182 into warehouse
# Successfully loaded employee 183 into warehouse
# Successfully loaded employee 184 into warehouse
# Successfully loaded employee 185 into warehouse
# Successfully loaded employee 186 into warehouse
# Successfully loaded employee 187 into warehouse
# Successfully loaded employee 188 into warehouse
# Successfully loaded employee 189 into warehouse
# Successfully loaded employee 190 into warehouse
# Successfully loaded employee 191 into warehouse
# Successfully loaded employee 192 into warehouse
# Successfully loaded employee 193 into warehouse
# Successfully loaded employee 194 into warehouse
# Successfully loaded employee 195 into warehouse
# Successfully loaded employee 196 into warehouse
# Successfully loaded employee 197 into warehouse
# Successfully loaded employee 198 into warehouse
# Successfully loaded employee 199 into warehouse
# Successfully loaded employee 200 into warehouse
# Successfully loaded employee 201 into warehouse
# Successfully loaded employee 202 into warehouse
# Successfully loaded employee 203 into warehouse
# Successfully loaded employee 204 into warehouse
# Successfully loaded employee 205 into warehouse
# Successfully loaded employee 206 into warehouse
# Successfully loaded employee 207 into warehouse
# Successfully loaded employee 208 into warehouse
# Successfully loaded employee 209 into warehouse
# Successfully loaded employee 210 into warehouse
# Successfully loaded employee 211 into warehouse
# Successfully loaded employee 212 into warehouse
# Successfully loaded employee 213 into warehouse
# Successfully loaded employee 214 into warehouse
# Successfully loaded employee 215 into warehouse
# Successfully loaded employee 216 into warehouse
# Successfully loaded employee 217 into warehouse
# Successfully loaded employee 218 into warehouse
# Successfully loaded employee 219 into warehouse
# Successfully loaded employee 220 into warehouse
# Successfully loaded employee 221 into warehouse
# Successfully loaded employee 222 into warehouse
# Successfully loaded employee 223 into warehouse
# Successfully loaded employee 224 into warehouse
# Successfully loaded employee 225 into warehouse
# Successfully loaded employee 226 into warehouse
# Successfully loaded employee 227 into warehouse
# Successfully loaded employee 228 into warehouse
# Successfully loaded employee 229 into warehouse
# Successfully loaded employee 230 into warehouse
# Successfully loaded employee 231 into warehouse
# Successfully loaded employee 232 into warehouse
# Successfully loaded employee 233 into warehouse
# Successfully loaded employee 234 into warehouse
# Successfully loaded employee 235 into warehouse
# Successfully loaded employee 236 into warehouse
# Successfully loaded employee 237 into warehouse
# Successfully loaded employee 238 into warehouse
# Successfully loaded employee 239 into warehouse
# Successfully loaded employee 240 into warehouse
# Successfully loaded employee 241 into warehouse
# Successfully loaded employee 242 into warehouse
# Successfully loaded employee 243 into warehouse
# Successfully loaded employee 244 into warehouse
# Successfully loaded employee 245 into warehouse
# Successfully loaded employee 246 into warehouse
# Successfully loaded employee 247 into warehouse
# Successfully loaded employee 248 into warehouse
# Successfully loaded employee 249 into warehouse
# Successfully loaded employee 250 into warehouse
# Successfully loaded employee 251 into warehouse
# Successfully loaded employee 252 into warehouse
# Successfully loaded employee 253 into warehouse
# Successfully loaded employee 254 into warehouse
# Successfully loaded employee 255 into warehouse
# Successfully loaded employee 256 into warehouse
# Successfully loaded employee 257 into warehouse
# Successfully loaded employee 258 into warehouse
# Successfully loaded employee 259 into warehouse
# Successfully loaded employee 260 into warehouse
# Successfully loaded employee 261 into warehouse
# Successfully loaded employee 262 into warehouse
# Successfully loaded employee 263 into warehouse
# Successfully loaded employee 264 into warehouse
# Successfully loaded employee 265 into warehouse
# Successfully loaded employee 266 into warehouse
# Successfully loaded employee 267 into warehouse
# Successfully loaded employee 268 into warehouse
# Successfully loaded employee 269 into warehouse
# Successfully loaded employee 270 into warehouse
# Successfully loaded employee 271 into warehouse
# Successfully loaded employee 272 into warehouse
# Successfully loaded employee 273 into warehouse
# Successfully loaded employee 274 into warehouse
# Successfully loaded employee 275 into warehouse
# Successfully loaded employee 276 into warehouse
# Successfully loaded employee 277 into warehouse
# Successfully loaded employee 278 into warehouse
# Successfully loaded employee 279 into warehouse
# Successfully loaded employee 280 into warehouse
# Successfully loaded employee 281 into warehouse
# Successfully loaded employee 282 into warehouse
# Successfully loaded employee 283 into warehouse
# Successfully loaded employee 284 into warehouse
# Successfully loaded employee 285 into warehouse
# Successfully loaded employee 286 into warehouse
# Successfully loaded employee 287 into warehouse
# Successfully loaded employee 288 into warehouse
# Successfully loaded employee 289 into warehouse
# Successfully loaded employee 290 into warehouse
# Successfully loaded employee 299 into warehouse
# Successfully loaded employee 316 into warehouse
# Successfully loaded employee 318 into warehouse
# Successfully loaded employee 390 into warehouse
# Successfully loaded employee 409 into warehouse
# Successfully loaded employee 445 into warehouse
# Successfully loaded employee 453 into warehouse
# Successfully loaded employee 467 into warehouse
# Successfully loaded employee 479 into warehouse
# Successfully loaded employee 501 into warehouse
# Successfully loaded employee 529 into warehouse
# Successfully loaded employee 582 into warehouse
# Successfully loaded employee 586 into warehouse
# Successfully loaded employee 591 into warehouse
# Successfully loaded employee 604 into warehouse
# Successfully loaded employee 641 into warehouse
# Successfully loaded employee 667 into warehouse
# Successfully loaded employee 690 into warehouse
# Successfully loaded employee 703 into warehouse
# Successfully loaded employee 750 into warehouse
# Successfully loaded employee 757 into warehouse
# Successfully loaded employee 839 into warehouse
# Successfully loaded employee 856 into warehouse
# Successfully loaded employee 862 into warehouse
# Successfully loaded employee 868 into warehouse
# Successfully loaded employee 879 into warehouse
# Successfully loaded employee 888 into warehouse
# Successfully loaded employee 902 into warehouse
# Successfully loaded employee 913 into warehouse
# Successfully loaded employee 921 into warehouse
# Successfully loaded employee 930 into warehouse
# Successfully loaded employee 949 into warehouse
# Successfully loaded employee 958 into warehouse
# Successfully loaded employee 992 into warehouse
# Successfully loaded employee 1013 into warehouse
# Successfully loaded employee 1021 into warehouse
# Successfully loaded employee 1039 into warehouse
# Successfully loaded employee 1062 into warehouse
# Successfully loaded employee 1090 into warehouse
# Successfully loaded employee 1101 into warehouse
# Successfully loaded employee 1142 into warehouse
# Successfully loaded employee 1157 into warehouse
# Successfully loaded employee 1162 into warehouse
# Successfully loaded employee 1191 into warehouse
# Successfully loaded employee 1250 into warehouse
# Successfully loaded employee 1293 into warehouse
# Successfully loaded employee 1336 into warehouse
# Successfully loaded employee 1390 into warehouse
# Successfully loaded employee 1446 into warehouse
# Successfully loaded employee 1483 into warehouse
# Successfully loaded employee 1507 into warehouse
# Successfully loaded employee 1570 into warehouse
# Successfully loaded employee 1576 into warehouse
# Successfully loaded employee 1596 into warehouse
# Successfully loaded employee 1607 into warehouse
# Successfully loaded employee 1615 into warehouse
# Successfully loaded employee 1643 into warehouse
# Successfully loaded employee 1658 into warehouse
# Successfully loaded employee 1684 into warehouse
# Successfully loaded employee 1740 into warehouse
# Successfully loaded employee 1751 into warehouse

# %% [markdown]
# ### Customer

# %%
def create_customer_row(id, address, city, zip, state, country, phone, first_name, last_name):
    def handle_nan(value):
        return None if pd.isnull(value) else value

    id = handle_nan(id)
    address = handle_nan(address)
    city = handle_nan(city)
    zip = handle_nan(zip)
    state = handle_nan(state)
    country = handle_nan(country)
    phone = handle_nan(phone)
    first_name = handle_nan(first_name)
    last_name = handle_nan(last_name)

    query = """
    INSERT INTO DimEmployee (
        CustomerID, Address, City, Zip, State,
        Country, Phone, FirstName, LastName
    ) VALUES (
        # %s, %s, %s, %s, %s, %s, %s, %s, %s 
    )
    """

    values = (id, address, city, zip, state, country, phone, first_name, last_name)

    try:
        warehouse_cursor.execute(query, values)
        print(f"Successfully loaded customer {id} into warehouse")
    except mysql.connector.Error as err:
        print(values)
        print(f"Failed to load customer into warehouse: {err}")

    warehouse_conn.commit()


staging_area_customer_data = pd.read_sql_query("SELECT * FROM Customer", staging_area_conn)

# the first time we will map the old customer ids to new ones
for row in staging_area_customer_data.itertuples():
    

# the second loop will be performed to put data into the tables
# we will use data from the first loop to give us information
# on what happend to the old ids so the relations will still be intact
for row in staging_area_customer_data.itertuples():
    id = row.CustomerID

    # all different sources use other methods for adresses so this will get messy
    # we leave address, city, zip, state and country for now

    phone = row.Phone

    first_name = row.fname
    last_name = row.lname

    # when first_name is None last_name is also None
    if pd.isnull(first_name) is None and not pd.isnull(row.PersonID):
        # we will get the person and get the first and last name from there
        person = pd.read_sql_query(
            f"SELECT FirstName, LastName FROM Person WHERE PersonID = {row.CustomerID}", staging_area_conn
        )
        if not person.empty:
            first_name = result.iloc[0].FirstName
            last_name = result.iloc[0].LastName

    create_customer_row(id, None, None, None, None, None, phone, first_name, last_name)
# Out:
# ('1', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('10', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('100', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('101', None, None, None, None, None, '2015558966', 'Michaels', 'Devlin')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('102', None, None, None, None, None, '2125558725', 'Beth', 'Reiser')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('103', None, None, None, None, None, '2155556513', 'Erin', 'Niedringhaus')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('104', None, None, None, None, None, '6155555463', 'Meghan', 'Mason')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('105', None, None, None, None, None, '3175558437', 'Laura', 'McCarthy')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('106', None, None, None, None, None, '2035553464', 'Paul', 'Phillips')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('107', None, None, None, None, None, '9195555152', 'Kelly', 'Colburn')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('108', None, None, None, None, None, '6155558926', 'Matthew', 'Goforth')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('109', None, None, None, None, None, '8195559539', 'Jessie', 'Gagliardo')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('110', None, None, None, None, None, '6145552496', 'Michael', 'Agliori')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11000', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11001', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11002', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11003', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11004', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11005', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11006', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11007', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11008', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11009', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11010', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11011', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11012', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11013', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11014', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11015', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11016', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11017', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11018', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11019', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11020', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11021', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11022', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11023', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11024', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11025', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11026', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11027', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11028', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11029', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11030', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11031', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11032', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11033', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11034', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11035', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11036', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11037', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11038', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11039', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11040', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11041', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11042', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11043', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11044', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11045', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11046', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11047', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11048', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11049', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11050', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11051', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11052', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11053', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11054', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11055', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11056', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11057', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11058', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11059', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11060', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11061', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11062', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11063', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11064', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11065', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11066', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11067', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11068', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11069', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11070', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11071', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11072', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11073', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11074', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11075', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11076', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11077', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11078', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11079', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11080', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11081', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11082', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11083', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11084', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11085', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11086', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11087', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11088', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11089', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11090', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11091', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11092', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11093', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11094', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11095', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11096', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11097', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11098', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11099', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('111', None, None, None, None, None, '3155554486', 'Dylan', 'Ricci')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11100', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11101', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11102', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11103', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11104', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11105', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11106', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11107', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11108', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11109', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11110', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11111', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11112', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11113', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11114', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11115', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11116', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11117', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11118', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11119', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11120', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11121', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11122', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11123', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11124', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11125', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11126', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11127', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11128', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11129', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11130', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11131', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11132', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11133', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11134', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11135', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11136', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11137', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11138', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11139', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11140', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11141', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11142', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11143', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11144', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11145', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11146', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11147', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11148', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11149', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11150', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11151', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11152', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11153', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11154', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11155', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11156', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11157', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11158', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11159', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11160', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11161', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11162', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11163', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11164', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11165', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11166', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11167', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11168', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11169', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11170', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11171', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11172', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11173', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11174', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11175', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11176', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11177', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11178', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11179', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11180', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11181', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11182', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11183', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11184', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11185', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11186', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11187', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11188', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11189', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11190', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11191', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11192', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11193', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11194', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11195', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11196', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11197', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11198', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11199', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('112', None, None, None, None, None, '6125555603', 'Shawn', 'McDonough')
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11200', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11201', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11202', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11203', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11204', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11205', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11206', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11207', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11208', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11209', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11210', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11211', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11212', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11213', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11214', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11215', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11216', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11217', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11218', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11219', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11220', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11221', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11222', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11223', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11224', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11225', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11226', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11227', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11228', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11229', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11230', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11231', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11232', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11233', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11234', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11235', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11236', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11237', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11238', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11239', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11240', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11241', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11242', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11243', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11244', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11245', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11246', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11247', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11248', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11249', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11250', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11251', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11252', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11253', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11254', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11255', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11256', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11257', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11258', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11259', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11260', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11261', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11262', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11263', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11264', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11265', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11266', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11267', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11268', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11269', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11270', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11271', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11272', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11273', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11274', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11275', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11276', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11277', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11278', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11279', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11280', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11281', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11282', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11283', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11284', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11285', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11286', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11287', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11288', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11289', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('11290', None, None, None, None, None, None, None, None)
# ...
# ('95', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('96', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('97', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('98', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('99', None, None, None, None, None, None, None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('ALFKI', None, None, None, None, None, '030-0074321', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('ANATR', None, None, None, None, None, '(5) 555-4729', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('ANTON', None, None, None, None, None, '(5) 555-3932', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('AROUT', None, None, None, None, None, '(171) 555-7788', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BERGS', None, None, None, None, None, '0921-12 34 65', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BLAUS', None, None, None, None, None, '0621-08460', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BLONP', None, None, None, None, None, '88.60.15.31', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BOLID', None, None, None, None, None, '(91) 555 22 82', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BONAP', None, None, None, None, None, '91.24.45.40', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BOTTM', None, None, None, None, None, '(604) 555-4729', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('BSBEV', None, None, None, None, None, '(171) 555-1212', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('CACTU', None, None, None, None, None, '(1) 135-5555', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('CENTC', None, None, None, None, None, '(5) 555-3392', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('CHOPS', None, None, None, None, None, '0452-076545', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('COMMI', None, None, None, None, None, '(11) 555-7647', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('CONSH', None, None, None, None, None, '(171) 555-2282', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('DRACD', None, None, None, None, None, '0241-039123', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('DUMON', None, None, None, None, None, '40.67.88.88', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('EASTC', None, None, None, None, None, '(171) 555-0297', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('ERNSH', None, None, None, None, None, '7675-3425', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FAMIA', None, None, None, None, None, '(11) 555-9857', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FISSA', None, None, None, None, None, '(91) 555 94 44', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FOLIG', None, None, None, None, None, '20.16.10.16', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FOLKO', None, None, None, None, None, '0695-34 67 21', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FRANK', None, None, None, None, None, '089-0877310', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FRANR', None, None, None, None, None, '40.32.21.21', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FRANS', None, None, None, None, None, '011-4988260', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('FURIB', None, None, None, None, None, '(1) 354-2534', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('GALED', None, None, None, None, None, '(93) 203 4560', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('GODOS', None, None, None, None, None, '(95) 555 82 82', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('GOURL', None, None, None, None, None, '(11) 555-9482', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('GREAL', None, None, None, None, None, '(503) 555-7555', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('GROSR', None, None, None, None, None, '(2) 283-2951', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('HANAR', None, None, None, None, None, '(21) 555-0091', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('HILAA', None, None, None, None, None, '(5) 555-1340', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('HUNGC', None, None, None, None, None, '(503) 555-6874', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('HUNGO', None, None, None, None, None, '2967 542', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('ISLAT', None, None, None, None, None, '(198) 555-8888', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('KOENE', None, None, None, None, None, '0555-09876', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LACOR', None, None, None, None, None, '30.59.84.10', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LAMAI', None, None, None, None, None, '61.77.61.10', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LAUGB', None, None, None, None, None, '(604) 555-3392', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LAZYK', None, None, None, None, None, '(509) 555-7969', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LEHMS', None, None, None, None, None, '069-0245984', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LETSS', None, None, None, None, None, '(415) 555-5938', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LILAS', None, None, None, None, None, '(9) 331-6954', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LINOD', None, None, None, None, None, '(8) 34-56-12', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('LONEP', None, None, None, None, None, '(503) 555-9573', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('MAGAA', None, None, None, None, None, '035-640230', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('MAISD', None, None, None, None, None, '(02) 201 24 67', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('MEREP', None, None, None, None, None, '(514) 555-8054', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('MORGK', None, None, None, None, None, '0342-023176', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('NORTS', None, None, None, None, None, '(171) 555-7733', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('OCEAN', None, None, None, None, None, '(1) 135-5333', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('OLDWO', None, None, None, None, None, '(907) 555-7584', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('OTTIK', None, None, None, None, None, '0221-0644327', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('PARIS', None, None, None, None, None, '(1) 42.34.22.66', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('PERIC', None, None, None, None, None, '(5) 552-3745', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('PICCO', None, None, None, None, None, '6562-9722', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('PRINI', None, None, None, None, None, '(1) 356-5634', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('QUEDE', None, None, None, None, None, '(21) 555-4252', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('QUEEN', None, None, None, None, None, '(11) 555-1189', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('QUICK', None, None, None, None, None, '0372-035188', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('RANCH', None, None, None, None, None, '(1) 123-5555', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('RATTC', None, None, None, None, None, '(505) 555-5939', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('REGGC', None, None, None, None, None, '0522-556721', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('RICAR', None, None, None, None, None, '(21) 555-3412', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('RICSU', None, None, None, None, None, '0897-034214', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('ROMEY', None, None, None, None, None, '(91) 745 6200', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SANTG', None, None, None, None, None, '07-98 92 35', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SAVEA', None, None, None, None, None, '(208) 555-8097', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SEVES', None, None, None, None, None, '(171) 555-1717', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SIMOB', None, None, None, None, None, '31 12 34 56', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SPECD', None, None, None, None, None, '(1) 47.55.60.10', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SPLIR', None, None, None, None, None, '(307) 555-4680', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('SUPRD', None, None, None, None, None, '(071) 23 67 22 20', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('THEBI', None, None, None, None, None, '(503) 555-3612', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('THECR', None, None, None, None, None, '(406) 555-5834', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('TOMSP', None, None, None, None, None, '0251-031259', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('TORTU', None, None, None, None, None, '(5) 555-2933', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('TRADH', None, None, None, None, None, '(11) 555-2167', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('TRAIH', None, None, None, None, None, '(206) 555-8257', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('VAFFE', None, None, None, None, None, '86 21 32 43', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('VICTE', None, None, None, None, None, '78.32.54.86', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('VINET', None, None, None, None, None, '26.47.15.10', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('WANDK', None, None, None, None, None, '0711-020361', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('WARTH', None, None, None, None, None, '981-443655', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('WELLI', None, None, None, None, None, '(14) 555-8122', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('WHITC', None, None, None, None, None, '(206) 555-4112', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('WILMK', None, None, None, None, None, '90-224 8858', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
# ('WOLZA', None, None, None, None, None, '(26) 642-7012', None, None)
# Failed to load customer into warehouse: 1054 (42S22): Unknown column 'CustomerID' in 'field list'
